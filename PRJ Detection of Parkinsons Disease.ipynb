# %%
Parkinsons Disease Detection

# %%
Import NumPy for numerical calculation, Pandas for handling data and visualization with Seaborn and Matplotlib

# %%
import os 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize']=(12,6)
sns.set
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
Import the dataset

# %%
os.chdir("C:\\Users\\kusha\\OneDrive\\Desktop\\Kushang's Files\\DS\\Resources")
os.getcwd()
# Out:
# "C:\\Users\\kusha\\OneDrive\\Desktop\\Kushang's Files\\DS\\Resources"

# %%
parkinsons_data=pd.read_csv('parkinsons.csv')

# %%
# Using shape function, we can observe the dimensions of the data
parkinsons_data.shape
# Out:
# (195, 24)

# %%
There are 24 columns and 195 observations

# %%
# We can observe the dataset using the head()function, which returns the first five records from the dataset
parkinsons_data.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
This project is a classification problem, from which we predict the binary variable "status" which can either be ill with Parkinson disease or not

# %%
# The info() method shows some of the characteristics of the data 
parkinsons_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
Statistical insights

# %%
parkinsons_data.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
Exploratory Data Analysis (EDA)

# %%
Let's build subplots of the features with boxplot or whisker plot to see the minimum, 1srt quantile, median and max.
Each time the feature is related to the status (0 or 1 for healthy or Parkinson disease)

# %%
fig, axes=plt.subplots(5,5,figsize=(15,15))
axes=axes.flatten()

for i in range(1,len(parkinsons_data.columns)-1):
    sns.boxplot(x='status', y=parkinsons_data.iloc[:,i], data=parkinsons_data, orient='v', ax=axes[i])
plt.tight_layout()
plt.show()

# %%
Thanks to these subplots we can easily see the outliers, the points that lie outside the whiskers.

# %%
# Let's have a closer look to the "PPE" variable
parkinsons_data.boxplot(column=['PPE'])
plt.show
# There are some outliers between 0.4 and 0.5 and beyond 0.5
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Data Cleaning

# %%
Removing duplicates and finding missing values are important, otherwise our models can lead us to incorrect conclusions

# %%
duplicate_Values=parkinsons_data.duplicated()
print(duplicate_Values.sum())
parkinsons_data[duplicate_Values]
# Out:
# 0
# Empty DataFrame
# Columns: [name, MDVP:Fo(Hz), MDVP:Fhi(Hz), MDVP:Flo(Hz), MDVP:Jitter(%), MDVP:Jitter(Abs), MDVP:RAP, MDVP:PPQ, Jitter:DDP, MDVP:Shimmer, MDVP:Shimmer(dB), Shimmer:APQ3, Shimmer:APQ5, MDVP:APQ, Shimmer:DDA, NHR, HNR, status, RPDE, DFA, spread1, spread2, D2, PPE]
# Index: []
#
# [0 rows x 24 columns]

# %%
There are no duplicate variables

# %%
print(parkinsons_data.isnull().sum())
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
Luckily, this dataset does not contain any missing values

# %%
Correlation Analysis

# %%
# Assuming parkinsons_data is your DataFrame
# Exclude non-numerical columns
numerical_data = parkinsons_data.select_dtypes(include=['number'])

# Compute the correlation matrix
corr = numerical_data.corr()

# Display the correlation matrix
print(corr)
# Out:
#                   MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# MDVP:Fo(Hz)          1.000000      0.400985      0.596546       -0.118003
# MDVP:Fhi(Hz)         0.400985      1.000000      0.084951        0.102086
# MDVP:Flo(Hz)         0.596546      0.084951      1.000000       -0.139919
# MDVP:Jitter(%)      -0.118003      0.102086     -0.139919        1.000000
# MDVP:Jitter(Abs)    -0.382027     -0.029198     -0.277815        0.935714
# MDVP:RAP            -0.076194      0.097177     -0.100519        0.990276
# MDVP:PPQ            -0.112165      0.091126     -0.095828        0.974256
# Jitter:DDP          -0.076213      0.097150     -0.100488        0.990276
# MDVP:Shimmer        -0.098374      0.002281     -0.144543        0.769063
# MDVP:Shimmer(dB)    -0.073742      0.043465     -0.119089        0.804289
# Shimmer:APQ3        -0.094717     -0.003743     -0.150747        0.746625
# Shimmer:APQ5        -0.070682     -0.009997     -0.101095        0.725561
# ...

# %%
We create a heatmap using Seaborn

# %%
# Assuming parkinsons_data is your DataFrame
# Exclude non-numerical columns
numerical_data = parkinsons_data.select_dtypes(include=['number'])

# Compute the correlation matrix
corr = numerical_data.corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='RdYlGn')
plt.title('Correlation Heatmap')
plt.show()

# %%
As it shown, it is not hard to find following pairs of highly correlated features:
Spread1 and PPE = 0,96

# %%
For a better visualization let's see below

# %%
sns.heatmap(corr[(corr>0.9)],annot=True,cmap='PuBu')
# Out:
# <Axes: >

# %%
We can also check the correlation between "spread1" and "PPE" variables thanks to "regplot" which plots the scartterplot plus the fitted regression line for the data.

# %%
sns.regplot(x='spread1', y='PPE', data=parkinsons_data)
# Out:
# <Axes: xlabel='spread1', ylabel='PPE'>

# %%
Let's go deeper with the P-value to know the significance of the correlation estimate when p-value is
< 0.001 leads to strong evidence
< 0.05 leads to moderate evidence
< 0.1 leads to weak evidence
> 0.1 leads to no evidence

# %%
from scipy import stats

# %%
pearson_coef, p_value = stats.pearsonr(parkinsons_data['spread1'], parkinsons_data['PPE'])
print ("The Pearson Correlation coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation coefficient is 0.962435293257281  with a P-value of P = 3.1338007401496195e-111

# %%
The linear relationship is strong between "spread1" and "PPE"(app. 0.96) and the correlation is statistically very significant

# %%
Let's explore some models, tune it to optimize its performance with the better predictability rate

# %%
Modeling

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn import tree
from os import system
from sklearn import metrics

# %%
# As we have seen previously, we can remove the non-numeric columns "name" and "status"
X = parkinsons_data.drop(['status', 'name'], axis = 1)
Y = parkinsons_data.status

# %%
Decision Tree Model

# %%
# Splitting Data into 70% Training data and 30% Testing Data
X_train, X_test, y_train,  y_test = train_test_split(X, Y,train_size=0.7, test_size=0.3, random_state=42)
print(len(X_train)),print(len(X_test))
# Out:
# 136
# 59
# (None, None)

# %%
# Applying decision tree model
decision_tree = DecisionTreeClassifier(criterion='entropy',max_depth=6,random_state=100,min_samples_leaf=5)
decision_tree.fit(X_train, y_train)
decision_tree.score(X_test , y_test)
# Out:
# 0.8983050847457628

# %%
y_pred = decision_tree.predict(X_test)
confusion_matrix(y_test,y_pred)
# Out:
# array([[11,  4],
#        [ 2, 42]], dtype=int64)

# %%
count_misclassified = (y_test != y_pred).sum()
print('Misclassified samples in Decision Tree: {}'.format(count_misclassified))
# Out:
# Misclassified samples in Decision Tree: 6

# %%
We've got 9 outliers samples

# %%
Random Forest

# %%
randomforest = RandomForestClassifier(n_estimators = 50)
randomforest = randomforest.fit(X_train, y_train)
y_pred = randomforest.predict(X_test)
randomforest.score(X_test , y_test)
# Out:
# 0.9322033898305084

# %%
count_misclassified = (y_test != y_pred).sum()
print('Misclassified samples in Random Forest: {}'.format(count_misclassified))
# Out:
# Misclassified samples in Random Forest: 4

# %%
We've got 4 outliers samples

# %%
feature_imp = pd.Series(randomforest.feature_importances_,index=X.columns).sort_values(ascending=False)
feature_imp

# Creating a bar plot
sns.barplot(x=feature_imp, y=feature_imp.index)

# Add labels to your graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
KNN

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
knn.score(X_test,y_test)
# Out:
# 0.8305084745762712

# %%
y_pred = knn.predict(X_test)
count_misclassified = (y_test != y_pred).sum()
print('Misclassified samples in KNN: {}'.format(count_misclassified))
# Out:
# Misclassified samples in KNN: 10

# %%
We've got 6 outliers samples

# %%
ADABoost

# %%
adb = AdaBoostClassifier( n_estimators= 50)
adb = adb.fit(X_train,y_train)
y_pred = adb.predict(X_test)
adb.score(X_test , y_test)
# Out:
# 0.8983050847457628

# %%
count_misclassified = (y_test != y_pred).sum()
print('Misclassified samples in Ada Boosting: {}'.format(count_misclassified))
# Out:
# Misclassified samples in Ada Boosting: 6

# %%
We've got 9 outliers samples

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

clf_dummy = DummyClassifier(random_state=42)
clf_dummy.fit(X_train, y_train)

# Generate predictions
y_pred = clf_dummy.predict(X_test)

# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.show()

# %%
y_train.value_counts(normalize=True)
# Out:
# status
# 1    0.757353
# 0    0.242647
# Name: proportion, dtype: float64

# %%
We have more people with Parkinson disease than people with not Parkinson
So the dummy classifier is predicting more people with the disease

# %%
Performance evaluation

# %%
With the confusion matrix we can have some metrics such as the accuracy, F1 score and the precision

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.7457627118644068

# %%
cm = confusion_matrix(y_test, y_pred)
print (cm)
# Out:
# [[ 0 15]
#  [ 0 44]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        15
#            1       0.75      1.00      0.85        44
#
#     accuracy                           0.75        59
#    macro avg       0.37      0.50      0.43        59
# weighted avg       0.56      0.75      0.64        59
